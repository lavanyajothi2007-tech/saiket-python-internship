# %% [markdown]
# <a href="https://colab.research.google.com/github/lavanyajothi2007-tech/saiket-python-internship/blob/main/Task_3_Basic_File_Handling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Creating a sample file
with open("sample.txt", "w") as file:
    file.write("Python is easy to learn.\nPython is powerful.")

# %%
try:
    # Reading the file
    with open("sample.txt", "r") as file:
        content = file.read()

    print("Original Content:\n", content)

    # Modifying the content
    updated_content = content.replace("Python", "PYTHON")

    # Writing back to the file
    with open("sample.txt", "w") as file:
        file.write(updated_content)

    print("\nUpdated Content:\n", updated_content)

except FileNotFoundError:
    print("File not found!")
# Out:
# Original Content:
#  Python is easy to learn.
# Python is powerful.
#
# Updated Content:
#  PYTHON is easy to learn.
# PYTHON is powerful.
