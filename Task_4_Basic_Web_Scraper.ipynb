# %% [markdown]
# <a href="https://colab.research.google.com/github/lavanyajothi2007-tech/saiket-python-internship/blob/main/Task_4_Basic_Web_Scraper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install beautifulsoup4 requests

# %%
import requests
from bs4 import BeautifulSoup

# URL to scrape
url = "https://example.com"

# Sending request to the website
response = requests.get(url)

# Parsing HTML content
soup = BeautifulSoup(response.text, "html.parser")

print("📌 Headings found on the webpage:\n")

# Extracting all h1 headings
for heading in soup.find_all("h1"):
    print(heading.text.strip())
# Out:
# 📌 Headings found on the webpage:
#
# Example Domain
