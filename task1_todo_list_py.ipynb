# %% [markdown]
# <a href="https://colab.research.google.com/github/lavanyajothi2007-tech/saiket-python-internship/blob/main/task1_todo_list_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
tasks = {}

def add_task():
    task = input("Enter task description: ")
    tasks[task] = "Pending"
    print("Task added successfully!")

def complete_task():
    task = input("Enter task to mark as completed: ")
    if task in tasks:
        tasks[task] = "Completed"
        print("Task marked as completed!")
    else:
        print("Task not found!")

def view_tasks():
    if not tasks:
        print("No tasks available.")
    else:
        for task, status in tasks.items():
            print(f"{task} - {status}")

while True:
    print("\n--- To-Do List Menu ---")
    print("1. Add Task")
    print("2. Complete Task")
    print("3. View Tasks")
    print("4. Exit")

    choice = input("Enter your choice: ")

    if choice == "1":
        add_task()
    elif choice == "2":
        complete_task()
    elif choice == "3":
        view_tasks()
    elif choice == "4":
        print("Exiting program.")
        break
    else:
        print("Invalid choice!")
# Out:
# --- To-Do List Menu ---
# 1. Add Task
# 2. Complete Task
# 3. View Tasks
# 4. Exit
